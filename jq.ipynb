# %% [markdown]
# <a href="https://colab.research.google.com/github/weagan/Tools/blob/main/jq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! sudo apt-get install jq
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# jq is already the newest version (1.6-2.1ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.
