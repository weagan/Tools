# %% [markdown]
# <a href="https://colab.research.google.com/github/weagan/Tools/blob/main/Remove_problematic_widget_metadata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# Load the notebook
file="/content/lora_vs_icl_indirect.ipynb"
with open(file, 'r') as f:
    notebook = json.load(f)

# Remove problematic widget metadata
if 'metadata' in notebook:
    if 'widgets' in notebook['metadata']:
        del notebook['metadata']['widgets']

# Save the fixed notebook
with open(file, 'w') as f:
    json.dump(notebook, f, indent=2)

print(f"✓ Fixed notebook saved as {file}")
# Out:
# ✓ Fixed notebook saved as /content/lora_vs_icl_indirect.ipynb
